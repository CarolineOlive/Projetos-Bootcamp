# %% [markdown]
# <a href="https://colab.research.google.com/github/CarolineOlive/Projetos-Bootcamp/blob/master/Caroline_Oliveira_Projeto_modulo_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Resumo
#
# ![Legal Ilustrado Games Infográfico (1).jpg](data:image/jpeg;base64,...)

# %% [markdown]
# LinkedIn: www.linkedin.com/in/caroline-oliveira-quim

# %% [markdown]
# #### Contextualização
# O câncer de mama e de colo do útero são os tipos de câncer que mais acometem mulheres no Brasil. O cancer de mama está em 1° lugar e representa 29,7% de novos casos de cancer no Brasil em 2020. É tambem o tipo de cancer com a maior taxa de mortalidade em mulheres, representando 16,4% do total de óbitos. O câncer de colo do útero é o 3° com maior incidencia e o 4° em mortalidade.
#
# Fonte: [Estatísticas de câncer](https://www.inca.gov.br/numeros-de-cancer)
#
# #### Projeto
# A proposta deste projeto é avaliar os dados de internações relacionadas as neoplasias malignas da mama e do colo do útero, no período de Jan/2008-Set/2020, usando como base o Ano/mês de processamento segundo Unidade da Federação.

# %% [markdown]
# # Câncer de mama e do colo do útero - Um panorâma do Brasil de 2008 a 2020

# %%
import pandas as pd

#importanto bibliotecas
import matplotlib.pyplot as plt
import numpy as np

# %%
# Importando o banco de dados de internações por câncer de mama e do colo do útero
dados_internacoes = pd.read_csv('/content/drive/MyDrive/Bootcamp Data Science/Módulo 1/Desafio 1/internações - cancer mama - cólo.csv', encoding="ISO-8859-1", na_values='-',
                    skiprows = 4, sep=";", skipfooter=6, thousands=".", decimal=",", engine='python')

# %%
# Importando o banco de dados de óbitos por câncer de mama e do colo do útero
dados_obito = pd.read_csv('/content/drive/MyDrive/Bootcamp Data Science/Módulo 1/Desafio 1/obito - cancer de mama - colo do utero.csv',  encoding="ISO-8859-1", na_values='-',
                    skiprows = 4, sep=";", skipfooter=6, thousands=".", decimal=",", engine='python')

# %%
dados_internacoes.head()
# Out:
#   Unidade da Federação  2008/Jan  2008/Fev  ...  2020/Ago  2020/Set  Total
# 0          11 Rondônia       1.0         2  ...        87      88.0   4692
# 1              12 Acre       5.0         5  ...        17       NaN   1848
# 2          13 Amazonas      18.0        80  ...        67      46.0   8592
# 3           14 Roraima       NaN         3  ...        12      19.0   1689
# 4              15 Pará      74.0        63  ...       110      22.0  12416
#
# [5 rows x 155 columns]

# %% [markdown]
# ### Número total de internações no país

# %%
# Para avaliar o total de internações no país
total_Brasil = dados_internacoes.iloc[[27]]
total_Brasil.drop('Total', axis=1, inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
total_Brasil = total_Brasil.set_index("Unidade da Federação")
total_Brasil
# Out:
#                       2008/Jan  2008/Fev  ...  2020/Ago  2020/Set
# Unidade da Federação                      ...
# Total                   3013.0      4461  ...      7050    7036.0
#
# [1 rows x 153 columns]

# %%
total_Brasil.T.plot(figsize=(10,6), colormap = "spring")
plt.title("Total de internações por câncer de mama e do colo do útero no Brasil - 2008 a 2020")
plt.legend("")
plt.show()

# %% [markdown]
# O gráfico nos permite observar o aumento do número de internações por cancêr de mama e do colo do útero com o passar dos anos.

# %% [markdown]
# ### Número total de internações por ano - 2008 a 2020

# %%
T_2008 = total_Brasil[["2008/Jan", "2008/Fev", "2008/Mar", "2008/Abr", "2008/Mai", "2008/Jun", "2008/Jul", "2008/Ago", "2008/Set", "2008/Out", "2008/Nov", "2008/Dez"]].sum().sum()
T_2009 = total_Brasil[["2009/Jan", "2009/Fev", "2009/Mar", "2009/Abr", "2009/Mai", "2009/Jun", "2009/Jul", "2009/Ago", "2009/Set", "2009/Out", "2009/Nov", "2009/Dez"]].sum().sum()
T_2010 = total_Brasil[["2010/Jan", "2010/Fev", "2010/Mar", "2010/Abr", "2010/Mai", "2010/Jun", "2010/Jul", "2010/Ago", "2010/Set", "2010/Out", "2010/Nov", "2010/Dez"]].sum().sum()
T_2011 = total_Brasil[["2011/Jan", "2011/Fev", "2011/Mar", "2011/Abr", "2011/Mai", "2011/Jun", "2011/Jul", "2011/Ago", "2011/Set", "2011/Out", "2011/Nov", "2011/Dez"]].sum().sum()
T_2012 = total_Brasil[["2012/Jan", "2012/Fev", "2012/Mar", "2012/Abr", "2012/Mai", "2012/Jun", "2012/Jul", "2012/Ago", "2012/Set", "2012/Out", "2012/Nov", "2012/Dez"]].sum().sum()
T_2013 = total_Brasil[["2013/Jan", "2013/Fev", "2013/Mar", "2013/Abr", "2013/Mai", "2013/Jun", "2013/Jul", "2013/Ago", "2013/Set", "2013/Out", "2013/Nov", "2013/Dez"]].sum().sum()
T_2014 = total_Brasil[["2014/Jan", "2014/Fev", "2014/Mar", "2014/Abr", "2014/Mai", "2014/Jun", "2014/Jul", "2014/Ago", "2014/Set", "2014/Out", "2014/Nov", "2014/Dez"]].sum().sum()
T_2015 = total_Brasil[["2015/Jan", "2015/Fev", "2015/Mar", "2015/Abr", "2015/Mai", "2015/Jun", "2015/Jul", "2015/Ago", "2015/Set", "2015/Out", "2015/Nov", "2008/Dez"]].sum().sum()
T_2016 = total_Brasil[["2016/Jan", "2016/Fev", "2016/Mar", "2016/Abr", "2016/Mai", "2016/Jun", "2016/Jul", "2016/Ago", "2016/Set", "2016/Out", "2016/Nov", "2016/Dez"]].sum().sum()
T_2017 = total_Brasil[["2017/Jan", "2017/Fev", "2017/Mar", "2017/Abr", "2017/Mai", "2017/Jun", "2017/Jul", "2017/Ago", "2017/Set", "2017/Out", "2017/Nov", "2017/Dez"]].sum().sum()
T_2018 = total_Brasil[["2018/Jan", "2018/Fev", "2018/Mar", "2018/Abr", "2018/Mai", "2018/Jun", "2018/Jul", "2018/Ago", "2018/Set", "2018/Out", "2018/Nov", "2018/Dez"]].sum().sum()
T_2019 = total_Brasil[["2019/Jan", "2019/Fev", "2019/Mar", "2019/Abr", "2019/Mai", "2019/Jun", "2019/Jul", "2019/Ago", "2019/Set", "2019/Out", "2019/Nov", "2019/Dez"]].sum().sum()
T_2020 = total_Brasil[["2020/Jan", "2020/Fev", "2020/Mar", "2020/Abr", "2020/Mai", "2020/Jun", "2020/Jul", "2020/Ago", "2020/Set"]].sum().sum()

print([T_2008, T_2009, T_2010, T_2011, T_2012, T_2013, T_2014, T_2015, T_2016, T_2017, T_2018, T_2019, T_2020])
# Out:
# [62851.0, 65129.0, 66789, 66557, 72054, 75900, 76282, 78053, 82663, 86172, 90251, 96758, 66915.0]

# %%
dado_por_ano = {'Ano' : [2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020], 
                'Total de internações' : [T_2008, T_2009, T_2010, T_2011, T_2012, T_2013, T_2014, T_2015, T_2016, T_2017, T_2018, T_2019, T_2020]}

# %%
total_Brasil_por_ano = pd.DataFrame(data=dado_por_ano)
total_Brasil_por_ano
# Out:
#      Ano  Total de internações
# 0   2008               62851.0
# 1   2009               65129.0
# 2   2010               66789.0
# 3   2011               66557.0
# 4   2012               72054.0
# 5   2013               75900.0
# 6   2014               76282.0
# 7   2015               78053.0
# 8   2016               82663.0
# 9   2017               86172.0
# 10  2018               90251.0
# 11  2019               96758.0
# 12  2020               66915.0

# %%
total_Brasil_por_ano.plot(x="Ano", y="Total de internações", kind='bar', figsize = (9, 7), color = 'fuchsia')
plt.title("Número de internações por câncer de mama e do colo do útero no Brasil")
plt.show()

# %% [markdown]
# O número de internações aumentou progressivamente de 2008 a 2019. O número obtido em 2019 representa um aumento de 54% em relação a 2008, chegando a quase 100 mil internações.

# %% [markdown]
# ### Unidades da Federação com maior número de internações

# %%
# criando um novo df sem a linha total para avaliar os dados pelas colunas
dados_sem_linha_total = dados_internacoes.drop(27)
dados_sem_linha_total.head()
# Out:
#   Unidade da Federação  2008/Jan  2008/Fev  ...  2020/Ago  2020/Set  Total
# 0          11 Rondônia       1.0         2  ...        87      88.0   4692
# 1              12 Acre       5.0         5  ...        17       NaN   1848
# 2          13 Amazonas      18.0        80  ...        67      46.0   8592
# 3           14 Roraima       NaN         3  ...        12      19.0   1689
# 4              15 Pará      74.0        63  ...       110      22.0  12416
#
# [5 rows x 155 columns]

# %%
# organizando os dados pelo número total de internações, em ordem decrescente, para identificar os Estados com maior número de internações.
dados_sort = dados_sem_linha_total.sort_values('Total', ascending=False)

# Visualizando o panorama geral do total de casos de cancer de mama e do colo do útero no período de Janeiro de 2008 a 2020 por unidade federativa
dados_sort.plot(x="Unidade da Federação", y="Total", kind = 'bar', figsize = (10, 7), color = 'magenta')
plt.title("Número total de internação por câncer de mama e do colo do útero por Unidade Federativa - 2008 a 2020")
plt.legend("")
plt.show()

# %% [markdown]
# Podemos observar que os estados com maior número total de internações são SP, MG, RJ, RS e PR.
#
# O número de internações parece ser menor nos estados da região Norte, sendo RO, AC, RR e AP os estados a ocuparem as ultimas posições.
#
# Diante desses dados, alguns questionamentos podem ser levantado:
# * esses dados sobre internações são proporcionais ao número de habitantes/estado?
# * Nos estados que apresentam um menor número de internações, o número de habitantes/estado é menor e, portanto, menor o número de internações?
# * há uma falha no diagnostico e, portanto, casos não são tratados/reportados e contabilizados corretamente?
# * há falha no momento de reportar os dados?

# %%
dados_sort.head()
# Out:
#     Unidade da Federação  2008/Jan  2008/Fev  ...  2020/Ago  2020/Set   Total
# 19          35 São Paulo     662.0       902  ...      1706    1847.0  231455
# 16       31 Minas Gerais     283.0       480  ...       753     812.0  111808
# 18     33 Rio de Janeiro     196.0       189  ...       731     759.0  101508
# 22  43 Rio Grande do Sul     306.0       478  ...       486     436.0   76600
# 20             41 Paraná     352.0       478  ...       576     515.0   76539
#
# [5 rows x 155 columns]

# %% [markdown]
# ### Região do País com maior número de casos

# %% [markdown]
# Uma forma ter uma visão mais clara dos dados apontados pelo gráfico 'Número total de internação por câncer de mama e do colo do útero por Unidade Federativa - 2008 a 2020' é agrupar os estados por região.

# %%
#Transformando a coluna 'Unidade da Federação' em indice para usá-lo na classificação por região.

dados_usaveis = dados_sort.set_index("Unidade da Federação")
dados_usaveis.head()
# Out:
#                       2008/Jan  2008/Fev  2008/Mar  ...  2020/Ago  2020/Set   Total
# Unidade da Federação                                ...
# 35 São Paulo             662.0       902      1244  ...      1706    1847.0  231455
# 31 Minas Gerais          283.0       480       640  ...       753     812.0  111808
# 33 Rio de Janeiro        196.0       189       666  ...       731     759.0  101508
# 43 Rio Grande do Sul     306.0       478       555  ...       486     436.0   76600
# 41 Paraná                352.0       478       515  ...       576     515.0   76539
#
# [5 rows x 154 columns]

# %%
# Criando uma nova coluna para associar uma região a cada estado.
# A partir do indice, foi selecionado apenas o primeiro número para usar como referência para as regiões
dados_usaveis["Região"] = dados_usaveis.index.str[0]

# criando um dicionário que associa a chave 'index'(estados) às correspondentes regiões. 
regiao_estado = {1:"Norte", 2:"Nordeste", 3:"Sudeste", 4:"Sul", 5:"Centro-Oeste"}

# criando uma função que associa o estado (key) à região (value) e cria a nova coluna.
dados_usaveis["Região"] = dados_usaveis["Região"].map(lambda x: regiao_estado[int(x)])

dados_usaveis["Região"]
# Out:
# Unidade da Federação
# 35 São Paulo                   Sudeste
# 31 Minas Gerais                Sudeste
# 33 Rio de Janeiro              Sudeste
# 43 Rio Grande do Sul               Sul
# 41 Paraná                          Sul
# 26 Pernambuco                 Nordeste
# 29 Bahia                      Nordeste
# 42 Santa Catarina                  Sul
# 23 Ceará                      Nordeste
# 32 Espírito Santo              Sudeste
# 52 Goiás                  Centro-Oeste
# 21 Maranhão                   Nordeste
# 22 Piauí                      Nordeste
# 53 Distrito Federal       Centro-Oeste
# 24 Rio Grande do Norte        Nordeste
# 25 Paraíba                    Nordeste
# 15 Pará                          Norte
# 27 Alagoas                    Nordeste
# 50 Mato Grosso do Sul     Centro-Oeste
# 51 Mato Grosso            Centro-Oeste
# 13 Amazonas                      Norte
# 17 Tocantins                     Norte
# 28 Sergipe                    Nordeste
# ...

# %%
dados_usaveis.head()
# Out:
#                       2008/Jan  2008/Fev  2008/Mar  ...  2020/Set   Total   Região
# Unidade da Federação                                ...
# 35 São Paulo             662.0       902      1244  ...    1847.0  231455  Sudeste
# 31 Minas Gerais          283.0       480       640  ...     812.0  111808  Sudeste
# 33 Rio de Janeiro        196.0       189       666  ...     759.0  101508  Sudeste
# 43 Rio Grande do Sul     306.0       478       555  ...     436.0   76600      Sul
# 41 Paraná                352.0       478       515  ...     515.0   76539      Sul
#
# [5 rows x 155 columns]

# %%
# Somando os numeros de internações dos estados por região
norte = dados_usaveis.query("Região == 'Norte'")["Total"].sum()
sul = dados_usaveis.query("Região == 'Sul'")["Total"].sum()
sudeste = dados_usaveis.query("Região == 'Sudeste'")["Total"].sum()
centro_oeste = dados_usaveis.query("Região == 'Centro-Oeste'")["Total"].sum()
nordeste = dados_usaveis.query("Região == 'Nordeste'")["Total"].sum()

# %%
# criando um dicionário para associar região e nº de internação
dados_regiao = {'Região': ["Norte", "Sul", "Sudeste", "Centro-Oeste", "Nordeste"], 'Total de Internações': [norte, sul, sudeste, centro_oeste, nordeste]}

# %%
# Criando um novo DataFrame com a região e o total de internações
dados_por_regiao = pd.DataFrame(data=dados_regiao)
dados_por_regiao
# Out:
#          Região  Total de Internações
# 0         Norte                 36865
# 1           Sul                193806
# 2       Sudeste                471710
# 3  Centro-Oeste                 59751
# 4      Nordeste                226075

# %% [markdown]
# #### Valores absolutos

# %%
regioes = dados_por_regiao.sort_values("Total de Internações", ascending=False)
regioes.plot(x="Região", y="Total de Internações", kind='bar', figsize = (9, 7), color = 'mediumvioletred')
plt.title("Número total de internação por câncer de mama e do colo do útero por Região do Brasil - 2008 a 2020")
plt.legend("")
plt.show()

# %% [markdown]
# Como indicado no gráfico anterior, olhando para os dados por região, vemos que a região Norte é a que apresenta o menor número de internações, sendo quase 13 vezes menor que o da regiação sudeste.

# %% [markdown]
# Quando observamos apenas o número absoluto de internações, sem considerar fatores como o número de habitantes por região/unidade federativa, corremos o risco de interpretar erroneamente os dados. Um estado com um menor número de internações e, também, de habitantes pode ter, proporcionalmente, o mesmo número de internações que um estados com maior número de habitantes e internações.
#
# Para verificar esse fator, vamos avaliar o número de habitantes por região do país.

# %%
regioes
# Out:
#          Região  Total de Internações
# 2       Sudeste                471710
# 4      Nordeste                226075
# 1           Sul                193806
# 3  Centro-Oeste                 59751
# 0         Norte                 36865

# %%
# criando uma nova coluna com o número de habitantes de cada região
regioes['Habitantes'] = [89012240, 57374243, 30192315, 18672591, 16504303]
regioes
# Out:
#          Região  Total de Internações  Habitantes
# 2       Sudeste                471710    89012240
# 4      Nordeste                226075    57374243
# 1           Sul                193806    30192315
# 3  Centro-Oeste                 59751    18672591
# 0         Norte                 36865    16504303

# %% [markdown]
# #### Proporção por milhão de habitantes

# %%
# para mostrar a proporção de internações por habitantes de uma forma mais clara, optei por transformar os valores em nº de internações por milhão de habitantes.
internacoes_por_milhao = (regioes["Total de Internações"] * 1000000) / regioes["Habitantes"]

# %%
# usei a função round para arredondar os valores obtidos
internacoes_por_milhao = round(internacoes_por_milhao, 0)

# %%
# criando uma nova coluna com o número de habitantes de cada região
regioes["Internações por Milhão de habitantes"] = internacoes_por_milhao
regioes
# Out:
#          Região  ...  Internações por Milhão de habitantes
# 2       Sudeste  ...                                5299.0
# 4      Nordeste  ...                                3940.0
# 1           Sul  ...                                6419.0
# 3  Centro-Oeste  ...                                3200.0
# 0         Norte  ...                                2234.0
#
# [5 rows x 4 columns]

# %%
regioes["Percentual"] = regioes["Total de Internações"] / regioes['Habitantes']
regioes
# Out:
#          Região  ...  Percentual
# 2       Sudeste  ...    0.005299
# 4      Nordeste  ...    0.003940
# 1           Sul  ...    0.006419
# 3  Centro-Oeste  ...    0.003200
# 0         Norte  ...    0.002234
#
# [5 rows x 5 columns]

# %%
regioes = regioes.sort_values("Internações por Milhão de habitantes", ascending=False)
regioes.plot(x="Região", y="Internações por Milhão de habitantes", kind='bar', figsize = (9, 7), color = 'deeppink')
plt.title("Número de internações por milhão de habitantes")
plt.legend("")
plt.show()

# %% [markdown]
# Em números totais, a região sul estava em 3° lugar em nº de internações. No entanto, proporcionalmente, é a região com maior número de internações. Já a região Norte, continua sendo a região com menor número.

# %% [markdown]
# ### Dados 2019

# %% [markdown]
# Olhando os dados mais recentes:

# %%
# removendo as colunas 'Total' e 'Região' para que os altos valores não interfiram na diferenciação dos outros valores.
dados_usaveis_1 = dados_usaveis.drop("Total", axis=1)
dados_usaveis_1 = dados_usaveis_1.drop("Região", axis=1)
dados_usaveis_1.head()
# Out:
#                       2008/Jan  2008/Fev  ...  2020/Ago  2020/Set
# Unidade da Federação                      ...
# 35 São Paulo             662.0       902  ...      1706    1847.0
# 31 Minas Gerais          283.0       480  ...       753     812.0
# 33 Rio de Janeiro        196.0       189  ...       731     759.0
# 43 Rio Grande do Sul     306.0       478  ...       486     436.0
# 41 Paraná                352.0       478  ...       576     515.0
#
# [5 rows x 153 columns]

# %%
#selecionando apenas os dados de 2019.
dados_2019 = dados_usaveis_1.iloc[:, [-21, -20, -19, -18, -17, -16, -15, -14, -13, -12, -11, -10]]
dados_2019.head()
# Out:
#                       2019/Jan  2019/Fev  ...  2019/Nov  2019/Dez
# Unidade da Federação                      ...
# 35 São Paulo              1931      1980  ...      2106      1936
# 31 Minas Gerais            862       835  ...       938       873
# 33 Rio de Janeiro          789       730  ...       809       737
# 43 Rio Grande do Sul       515       515  ...       575       497
# 41 Paraná                  633       634  ...       642       563
#
# [5 rows x 12 columns]

# %%
# adicionando uma nova coluna 'Total', que representa do total em 2019.
dados_2019["Total"] = dados_2019.sum(axis=1)
dados_2019.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                       2019/Jan  2019/Fev  2019/Mar  ...  2019/Nov  2019/Dez  Total
# Unidade da Federação                                ...
# 35 São Paulo              1931      1980      1927  ...      2106      1936  23840
# 31 Minas Gerais            862       835       882  ...       938       873  10658
# 33 Rio de Janeiro          789       730       804  ...       809       737   9910
# 43 Rio Grande do Sul       515       515       516  ...       575       497   6560
# 41 Paraná                  633       634       561  ...       642       563   7366
#
# [5 rows x 13 columns]

# %% [markdown]
# #### Valores absolutos

# %%
print("Em 2019 o número total de internações por câncer de mama e do colo do útero foi", dados_2019["Total"].sum())
# Out:
# Em 2019 o número total de internações por câncer de mama e do colo do útero foi 96758

# %%
# ordenando os dados pelo 'Total'
dados_2019_use = dados_2019.sort_values("Total", ascending=False)

dados_2019_use["Total"].plot(figsize=(10,6), kind='bar', color = 'hotpink')
plt.title("Numero de internações por Unidade da Federação - Ano 2019")
plt.show()

# %% [markdown]
# Em dados absolutos, o cenário de 2019 não se diferencia muito do cenário dos anos de 2008 a 2020. No entanto, para fazer uma melhor avaliação das unidades federativas, precisamos considerar o número de habitantes.

# %%
dados_2019_use.index
# Out:
# Index(['35 São Paulo', '31 Minas Gerais', '33 Rio de Janeiro', '41 Paraná',
#        '43 Rio Grande do Sul', '26 Pernambuco', '29 Bahia',
#        '42 Santa Catarina', '23 Ceará', '32 Espírito Santo', '52 Goiás',
#        '21 Maranhão', '25 Paraíba', '24 Rio Grande do Norte', '15 Pará',
#        '53 Distrito Federal', '27 Alagoas', '22 Piauí', '51 Mato Grosso',
#        '13 Amazonas', '50 Mato Grosso do Sul', '11 Rondônia', '28 Sergipe',
#        '17 Tocantins', '12 Acre', '14 Roraima', '16 Amapá'],
#       dtype='object', name='Unidade da Federação')

# %%
# criando uma lista com a população de cada UF
UF_habitantes = [46289333, 21331292, 17366189, 11516840, 11422973, 9616621, 14930634, 7279638, 9187103, 4064052, 7142070, 7127460, 
 4039277, 3534165, 8690745, 3055149, 3351543, 3281480, 3526220, 4228381, 2809394, 1796460, 2318822, 1590248, 894470, 631181, 861773]

# %%
# criando uma nova coluna com o número de habitantes de cada UF
dados_2019_use['Habitantes'] = UF_habitantes
dados_2019_use.head()
# Out:
#                       2019/Jan  2019/Fev  2019/Mar  ...  2019/Dez  Total  Habitantes
# Unidade da Federação                                ...
# 35 São Paulo              1931      1980      1927  ...      1936  23840    46289333
# 31 Minas Gerais            862       835       882  ...       873  10658    21331292
# 33 Rio de Janeiro          789       730       804  ...       737   9910    17366189
# 41 Paraná                  633       634       561  ...       563   7366    11516840
# 43 Rio Grande do Sul       515       515       516  ...       497   6560    11422973
#
# [5 rows x 14 columns]

# %% [markdown]
# #### Proporção por cem mil habitantes

# %%
# como feito anteriormente, para mostrar a proporção de internações por habitantes de uma forma mais clara, optei por transformar os valores em nº de internações por cem mil habitantes.
internacoes_UF_por_cem_mil = (dados_2019_use["Total"] * 100000) / dados_2019_use["Habitantes"]

# usei a função round para arredondar os valores obtidos
internacoes_UF_por_cem_mil = round(internacoes_UF_por_cem_mil, 0) 

# criando uma nova coluna com o número de habitantes de cada UF
dados_2019_use["Internações por Cem mil habitantes"] = internacoes_UF_por_cem_mil
dados_2019_use.head()
# Out:
#                       2019/Jan  ...  Internações por Cem mil habitantes
# Unidade da Federação            ...
# 35 São Paulo              1931  ...                                52.0
# 31 Minas Gerais            862  ...                                50.0
# 33 Rio de Janeiro          789  ...                                57.0
# 41 Paraná                  633  ...                                64.0
# 43 Rio Grande do Sul       515  ...                                57.0
#
# [5 rows x 15 columns]

# %%
# ordenando os dados pelo 'Total'
dados_2019_use_1 = dados_2019_use.sort_values("Internações por Cem mil habitantes", ascending=False)

dados_2019_use_1["Internações por Cem mil habitantes"].plot(figsize=(10,6), kind='bar', color = 'palevioletred')
plt.title("Proporção de internações por cem mil habitantes - Ano 2019")
plt.ylabel = ("Internações x 100 mil habitantes")
plt.show()

# %% [markdown]
# Avaliando o nº de internações das unidades federativas pelo nº de habitantes, vemos uma realidade escondida nos dados absolutos. Apesar do estado de SP ter o maior nº abosulto de internações, ele ocupa o 7° lugar em proporção. Já o ES que estava em 10° lugar em números absolutos, mostra uma realidade diferente, ficando em 1° lugar em nº de internações a cada 100 mil habitantes.
#
# Mato Grosso do Sul, estado onde moro atualmente, está em 15° lugar em nº de internações a cada 100 mil habitantes.

# %%
# mostrando os valores absolutos ordenados proporção por habitantes
dados_2019_use_1["Total"].plot(figsize=(10,6), kind='bar', color = 'hotpink')
plt.title("Numero de internações por Unidade da Federação - Ano 2019")
plt.show()

# %% [markdown]
# ### Óbitos

# %% [markdown]
# Os dados do instituto nacional de câncer (INCA) mostram que o cancer de mama é o tipo de cancer que mais mata mulheres no Brasil, seguido pelo câncer de cólon e reto (2º) e colo do útero (3º).
#
# Vimos que os números de internações são altos que a proporção por habitante traz um alerta para alguns estados. Dentro desse cenário, é interessante avaliarmos, tambem, a taxa de mortalidade nessas UF's em 2019.

# %%
# usando o banco de dados de óbitos pode câncer de mama e colo do útero para obter o total de óbitos em 2019
dados_obito.head()
# Out:
#   Unidade da Federação  2008/Jan  2008/Fev  ...  2020/Ago  2020/Set  Total
# 0          11 Rondônia       NaN       NaN  ...       9.0       3.0    423
# 1              12 Acre       1.0       NaN  ...       2.0       NaN    207
# 2          13 Amazonas       NaN       2.0  ...      14.0       9.0    963
# 3           14 Roraima       NaN       NaN  ...       NaN       NaN    182
# 4              15 Pará       3.0       2.0  ...      15.0       4.0   1741
#
# [5 rows x 155 columns]

# %%
# removendo a linha 'Total'
dados_obito_sem_total = dados_obito.drop(27)

# %%
#Transformando a coluna 'Unidade da Federação' em indice
dados_obito_usaveis = dados_obito_sem_total.set_index("Unidade da Federação")

# %%
#selecionando apenas os dados de 2019.
dados_obito_2019 = dados_obito_usaveis.iloc[:, [-22, -21, -20, -19, -18, -17, -16, -15, -14, -13, -12, -11]]

# %%
# adicionando uma nova coluna 'Total', que representa do total de óbitos em 2019.
dados_obito_2019["Total"] = dados_obito_2019.sum(axis=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# ordenando os dados pelo indice
internacao_obito = dados_2019_use_1.sort_values("Unidade da Federação")

# %%
#criando um lista com o número total de óbitos em cada UF em 2019 
obitos = [62.0, 18.0, 145.0, 31.0, 204.0, 23.0, 43.0, 254.0, 62.0, 170.0, 105.0, 157.0, 569.0, 138.0, 65.0, 467.0, 762.0, 219.0, 1260.0, 2138.0, 522.0, 321.0, 
          512.0, 123.0, 74.0, 215.0, 134.0]

# %%
# adicionando o total de óbitos em 2019 ao dataframe de internações em 2019
internacao_obito["Total de Óbitos"] = obitos

# %%
# ordenando os dados pelo 'Internações por Cem mil habitantes'
internacao_obito_1 = internacao_obito.sort_values("Internações por Cem mil habitantes", ascending=False)

# %%
# para calcular a taxa de mortalidade em porcentagem, dividi o nº total de óbitos pelo nº total de internações e multipliquei por 100.
taxa_mortalidade = (internacao_obito_1["Total de Óbitos"] / internacao_obito_1["Total"]) * 100
taxa_mortalidade = round(taxa_mortalidade, 0)

# %%
# criando a coluna 'Taxa de Mortalidade'
internacao_obito_1["Taxa de mortalidade"] = taxa_mortalidade

# %%
# nº de óbitos em 2019
internacao_obito["Total de Óbitos"].sum()
# Out:
# 8793.0

# %%
internacao_obito_1.head()
# Out:
#                       2019/Jan  2019/Fev  ...  Total de Óbitos  Taxa de mortalidade
# Unidade da Federação                      ...
# 32 Espírito Santo          213       212  ...            219.0                  8.0
# 41 Paraná                  633       634  ...            522.0                  7.0
# 26 Pernambuco              461       439  ...            569.0                  9.0
# 43 Rio Grande do Sul       515       515  ...            512.0                  8.0
# 33 Rio de Janeiro          789       730  ...           1260.0                 13.0
#
# [5 rows x 17 columns]

# %% [markdown]
# #### Taxa de mortalidade

# %%
#ordenando os dados pela taxa de mortalidade
internacao_obito_taxa = internacao_obito_1.sort_values("Taxa de mortalidade", ascending=False)

#Visualização da taxa de mortalidade por UF em ordem decrescente
internacao_obito_taxa["Taxa de mortalidade"].plot(figsize=(10,6), kind='bar', color = ['purple'])
plt.title("Taxa de mortalidade (%) por câncer de mama e colo do útero em 2019")
plt.show()

# %% [markdown]
# Podemos observar que a taxa de mortalidade traz um outro cenário onde os estados da região Norte apresentam o maior percentual.
# Mato Grosso do Sul  é o 6° estado com maior taxa de mortalidade.

# %% [markdown]
# ### Conclusão
#
# O número de internações por câncer de mama e colo do útero tem crescido ao longo dos anos, o que indica um aumento no número de casos.
# A região sul está em 1° lugar em número de internações por habitantes, indicando, também, maior incidencia de casos.
# Por outro lado, a taxa de mortalidade em estados da região norte são as maiores.
#
# Os dados de taxa de mortalidade nos dá um alerta da necessidade de avaliar e tratar as causas que elevam a taxa de mortalidade desses estados, visto que os mesmo apresentam números de internações baixos, quando comparados com estados de outras regiões do país.

# %% [markdown]
# ### Referência bibliográfica:
#
# Dados: [DataSus](http://www2.datasus.gov.br/DATASUS/index.php?area=02) <acesso em nov/2020)
#
# [Lista de unidades federativas do Brasil por população](https://pt.wikipedia.org/wiki/Lista_de_unidades_federativas_do_Brasil_por_popula%C3%A7%C3%A3o) <acesso em nov/2020>
#
# [Estatísticas de câncer](https://www.inca.gov.br/numeros-de-cancer) <acesso em nov/2020>
